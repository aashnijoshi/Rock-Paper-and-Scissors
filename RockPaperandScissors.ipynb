# %% [markdown]
# <a href="https://colab.research.google.com/github/aashnijoshi/Rock-Paper-and-Scissors/blob/main/RockPaperandScissors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title rock, paper and scissors
print("rock, paper and scissors")
import random
pc=0
py=0

while  pc<5 and py<5:
  a = input("do you choose rock, papers or scissors? please enter r for rock, p for paper and s for scissors")
  b=int(random.randint(1,3))
  if a=="r":
    if b==1:
      print("the computer rolled: ROCK! ")
      print("roll again! ")
    elif b==2:
      print("the computer rolled SCISSORS!")
      print("you win a point! ")  
      py+=1
    else:
      print("the computer rolled PAPER!")
      print("aw, you lose this round...")  
      pc+=1
    print(" ")  
    print(" ")    
    print("your score ="+ str(py))  
    print("computer's score="+str(pc))
  elif a=='p':
    if b==1:
      print("the computer rolled PAPER!")
      print("roll again! ")
    elif b==2:
      print("the computer rolled: ROCK! ")
      print("you win a point! ")  
      py+=1
    else:
      print("the computer rolled SCISSORS!")
      print("aw, you lose this round...")  
      pc+=1
    print(" ")  
    print(" ")    
    print("your score ="+ str(py))  
    print("computer's score="+str(pc))
  else:
    if b==1:
      print("the computer rolled SCISSORS!")
      print("roll again! ")
    elif b==2:
      print("the computer rolled PAPER!")
      print("you win a point! ")  
      py+=1
    else:
      print("the computer rolled: ROCK! ")
      print("aw, you lose this round...")  
      pc+=1
    print(" ")  
    print(" ")  
    print("your score ="+ str(py))  
    print("computer's score="+str(pc))  
  
if pc==5:
  print("oh no! you lost the game")

elif py==5:
  print("winner winner chicken dinner!")
# Out:
# rock, paper and scissors
# do you choose rock, papers or scissors? please enter r for rock, p for paper and s for scissorss
# the computer rolled: ROCK!
# aw, you lose this round...
#
#
# your score =0
# computer's score=1
# do you choose rock, papers or scissors? please enter r for rock, p for paper and s for scissorsp
# the computer rolled SCISSORS!
# aw, you lose this round...
#
#
# your score =0
# computer's score=2
# do you choose rock, papers or scissors? please enter r for rock, p for paper and s for scissorsp
# the computer rolled PAPER!
# roll again!
#
#
# your score =0
# computer's score=2
# do you choose rock, papers or scissors? please enter r for rock, p for paper and s for scissorsp
# the computer rolled SCISSORS!
# aw, you lose this round...
#
#
# your score =0
# computer's score=3
# do you choose rock, papers or scissors? please enter r for rock, p for paper and s for scissorsp
# the computer rolled SCISSORS!
# aw, you lose this round...
#
#
# your score =0
# ...
